# %%
import bs4
import lxml
import pandas as pd
import urllib
import numpy
import retrieve
from bs4 import BeautifulSoup

# %%
# Onlt spring (and winter for LEC) tournaments from 2024 are complete, the rest didn't take place yet
tournaments2024 = ["https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Season%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Winter%20Playoffs%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Winter%20Season%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%20Playoffs%202024/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202024/"]

tournaments2023 = ["https://gol.gg/tournament/tournament-matchlist/Worlds%20Main%20Event%202023/",
               "https://gol.gg/tournament/tournament-matchlist/Worlds%20Play-In%202023/",
               "https://gol.gg/tournament/tournament-matchlist/Worlds%20Qualifying%20Series%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Season%20Finals%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Groups%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Groups%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Season%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Winter%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Winter%20Groups%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LEC%20Winter%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCK%20Regional%20Finals%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCS%20Championship%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LPL%20Regional%20Finals%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%20Playoffs%202023/",
               "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%202023/",
               "https://gol.gg/tournament/tournament-matchlist/MSI%202023/",]

tournaments2022 = ["https://gol.gg/tournament/tournament-matchlist/World%20Championship%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/World%20Championship%20Play-In%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Championship%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Regionals%20Finals%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Regional%20Finals%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%202022/",
                   "https://gol.gg/tournament/tournament-matchlist/MSI%202022/"]

tournaments2021 = ["https://gol.gg/tournament/tournament-matchlist/World%20Championship%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/World%20Championship%20Play-In%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Championship%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Mid-Season%20Showdown%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Regional%20Finals%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Regional%20Finals%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%202021/",
                   "https://gol.gg/tournament/tournament-matchlist/MSI%202021/"]

tournaments2020 = ["https://gol.gg/tournament/tournament-matchlist/World%20Championship%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/World%20Championship%20Play-In%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Regional%20Finals%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Promotion%202020/"
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Regional%20Finals%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%202020/"]

tournaments2019 = ["https://gol.gg/tournament/tournament-matchlist/World%20Championship%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/World%20Championship%20Play-In%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Regional%20Finals%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Summer%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCS%20Spring%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Promotion%202020/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Regional%20Finals%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Summer%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LCK%20Spring%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Regional%20Finals%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Summer%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LPL%20Spring%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Regional%20Finals%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Summer%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%20Playoffs%202019/",
                    "https://gol.gg/tournament/tournament-matchlist/LEC%20Spring%202019/"] # 2019 Tournament URLs, might be skipped as the other dataset goes from 2020 to 2023

# %%
def get_region(link):
    if "World" in link:
        return "WORLDS"
    elif "LEC" in link:
        return "LEC"
    elif "LCK" in link:
        return "LCK"
    elif "LPL" in link:
        return "LPL"
    elif "LCS" in link:
        return "LCS"
    elif "MSI" in link:
        return "MSI"
    else:
        return "Other"

#tournaments2023_tuples = [(link, get_region(link), 2023) for link in tournaments2023]
#tournaments2022_tuples = [(link, get_region(link), 2022) for link in tournaments2022]
#tournaments2021_tuples = [(link, get_region(link), 2021) for link in tournaments2021]
#tournaments2020_tuples = [(link, get_region(link), 2020) for link in tournaments2020]
#tournaments2019_tuples = [(link, get_region(link), 2019) for link in tournaments2019]

#tournaments = tournaments2023_tuples + tournaments2022_tuples + tournaments2021_tuples + tournaments2020_tuples

#display(tournaments)

# %%
def get_matches(tournament_url, region, year):
    page = retrieve.firefoxPage(tournament_url)
    soup = BeautifulSoup(page, 'lxml')
    match_list = soup.find('table').find('tbody')
    matches = []
    for match in match_list:
        try : suffix = match.find('a').get('href')
        except :
            display(match) # Apparently it's the match betwen GEN and BRO in 2022 where GIGABRO FF'd so there's no link / details
        # Checking if it is really a match suffix by checking if it is in the format like : "../game/stats/26935/page-summary/"
        if "../game/stats/" in suffix:
            suffix = suffix[2:] # Removing the first two characters which are ".."
            match_link = "https://gol.gg" + suffix
            matches.append((match_link, region, year))
    return matches

# print(get_matches(tournaments[0][0], tournaments[0][1]))

def get_all_matches(tournaments):
    matches = []
    for tournament in tournaments:
        matches.extend(get_matches(tournament[0], tournament[1], tournament[2]))
    return matches

#matches = get_all_matches(tournaments)
#display(matches)

# %%
def get_games(match_url, region, year):
    page = retrieve.firefoxPage(match_url)
    soup = BeautifulSoup(page, 'lxml')
    game_links = []
    for link in soup.find_all('a'):
        href = link.get('href')
        if href and "/game/stats/" in href and "/page-game/" in href:
            suffix = href[2:]
            link = "https://gol.gg" + suffix
            game_links.append((link, region, year))
    return game_links

# print(matches[0][0])
# print(get_games(matches[0][0], matches[0][1], matches[0][2]))

def get_all_games(matches):
    games = []
    for match in matches:
        games.extend(get_games(match[0], match[1], match[2]))
    return games

#games = get_all_games(matches)

# %%
df = pd.DataFrame(games, columns=["Link", "Region", "Year"])
df.to_csv("../data/games_links.csv", index=False)

# view length of games

display(len(games))
# Out:
# 9639

# %%
df = pd.read_csv("../data/games_links.csv")

# %%
def get_game_result(game_url, region, year):
    page = retrieve.firefoxPage(game_url)
    soup = BeautifulSoup(page, 'lxml')

    blueside = soup.find_all('div', class_="col-12 blue-line-header")
    redside = soup.find_all('div', class_="col-12 red-line-header")
    
    if not blueside or not redside:
        return None
    
    game_duration = soup.find('div', class_="col-6 text-center").find('h1').text


    blueside_team = blueside[0].find('a').text
    redside_team = redside[0].find('a').text
    blueside_victory = "WIN" in blueside[0].text
    redside_victory = "WIN" in redside[0].text

    return (blueside_team, blueside_victory, redside_team, redside_victory, game_duration, region, year)

#get_game_result(df["Link"][0], df["Region"][0], df["Year"][0])

# %%
def get_game_stats(game_url, region, year, blue_team, red_team, blue_win, red_win, duration):
    # replacing page-game/ suffix into page-fullstats/ in the game_url
    game_url = game_url.replace("page-game/", "page-fullstats/")
    page = retrieve.firefoxPage(game_url)
    soup = BeautifulSoup(page, 'lxml')
    label = ["Side", "Region", "Year", "Game ID", "Team", "Victory", "Game Duration"]
    initial_size = len(label)
    print(game_url)
    # https://gol.gg/game/stats/57150/page-fullstats/, getting the id between stats/ and /*****
    game_id = game_url.split("stats/")[1].split("/")[0]
    player_data = []
    for i in range(5):
        player_data.append(["Blue Side", region, year, game_id, blue_team, blue_win, duration])
    for i in range(5):
        player_data.append(["Red Side", region, year, game_id, red_team, red_win, duration])
    table = soup.find_all('tr')
    for row in table:
        td = row.find('td')
        if not td:
            continue
        label.append(td.text)
        for i, cell in enumerate(row.find_all('td')[1:]):
            player_data[i].append(cell.text)
    if (len(label) != len(player_data[0])):
        return None
    return pd.DataFrame(player_data, columns=label)

def get_game_full(game_url, region, year):
    game_result = get_game_result(game_url, region, year)
    if not game_result:
        return None
    blue_team, blue_win, red_team, red_win, duration, region, year = get_game_result(game_url, region, year)
    return get_game_stats(game_url, region, year, blue_team, red_team, blue_win, red_win, duration)
    
#print(get_game_full(df["Link"][0], df["Region"][0], df["Year"][0]))

# %%
def get_all_game_full(df):
    for i in range(len(df)):
        if i == 0:
            full_data = get_game_full(df["Link"][i], df["Region"][i], df["Year"][i])
        else:
            res = get_game_full(df["Link"][i], df["Region"][i], df["Year"][i])
            if res is not None:
                full_data = pd.concat([full_data, res])
    return full_data

#full_data = get_all_game_full(df)

# %%
def get_10_game_full(df):
    for i in range(10):
        if i == 0:
            full_data = get_game_full(df["Link"][i], df["Region"][i], df["Year"][i])
        else:
            res = get_game_full(df["Link"][i], df["Region"][i], df["Year"][i])
            if res is not None:
                full_data = pd.concat([full_data, res])
    return full_data

# %%
def normalize_df(df):
    percentages = ['GOLD%', 'VS%', 'DMG%', 'KP%']
    numeric_cols = df.columns[9:].drop(['KDA', 'CS in Enemy Jungle'])\
    
    perfect_kda_score = '100'
    
    norm_df = df.copy()
    
    for percentage in percentages:
        norm_df[percentage] = pd.to_numeric(df[percentage].str.replace('%', ''), errors='coerce').astype(float) / 100
    
    norm_df['Game Duration'] = norm_df['Game Duration'].str[:2].astype(float) + round(norm_df['Game Duration'].str[3:].astype(float)  / 60, 3)
    
    norm_df['Solo kills'] = norm_df['Solo kills'].str.replace('', '0')
    
    norm_df['KDA'] = norm_df['KDA'].str.replace('Perfect KDA', perfect_kda_score).astype(float)
    
    for columns in numeric_cols:
        norm_df[columns] = pd.to_numeric(norm_df[columns], errors='coerce', downcast='float')
    
    return norm_df

# %%
_10data = get_10_game_full(df)
# Out:
# https://gol.gg/game/stats/53622/page-fullstats/
# https://gol.gg/game/stats/53623/page-fullstats/
# https://gol.gg/game/stats/53624/page-fullstats/
# https://gol.gg/game/stats/53618/page-fullstats/
# https://gol.gg/game/stats/53619/page-fullstats/
# https://gol.gg/game/stats/53620/page-fullstats/
# https://gol.gg/game/stats/53621/page-fullstats/
# https://gol.gg/game/stats/53613/page-fullstats/
# https://gol.gg/game/stats/53614/page-fullstats/
# https://gol.gg/game/stats/53615/page-fullstats/

# %%
normalize_df(_10data).to_csv('../data/10data.csv', sep=',')

# %%
normalize_df(full_data).to_csv('../data/game_data.csv', sep=',')

# %%
# Getting game data from 2024

tournaments2024_tuples = [(link, get_region(link), 2024) for link in tournaments2024]

tournaments = tournaments2024_tuples
matches = get_all_matches(tournaments)
games = get_all_games(matches)
game_links = pd.DataFrame(games, columns=["Link", "Region", "Year"])

# %%
full_data = get_all_game_full(game_links)
normalize_df(full_data).to_csv('../data/game_data2024.csv', sep=',')
# Out:
# https://gol.gg/game/stats/57862/page-fullstats/
# https://gol.gg/game/stats/57863/page-fullstats/
# https://gol.gg/game/stats/57864/page-fullstats/
# https://gol.gg/game/stats/57865/page-fullstats/
# https://gol.gg/game/stats/57814/page-fullstats/
# https://gol.gg/game/stats/57815/page-fullstats/
# https://gol.gg/game/stats/57816/page-fullstats/
# https://gol.gg/game/stats/57817/page-fullstats/
# https://gol.gg/game/stats/57818/page-fullstats/
# https://gol.gg/game/stats/57789/page-fullstats/
# https://gol.gg/game/stats/57790/page-fullstats/
# https://gol.gg/game/stats/57791/page-fullstats/
# https://gol.gg/game/stats/57792/page-fullstats/
# https://gol.gg/game/stats/57673/page-fullstats/
# https://gol.gg/game/stats/57674/page-fullstats/
# https://gol.gg/game/stats/57675/page-fullstats/
# https://gol.gg/game/stats/57676/page-fullstats/
# https://gol.gg/game/stats/57786/page-fullstats/
# https://gol.gg/game/stats/57787/page-fullstats/
# https://gol.gg/game/stats/57783/page-fullstats/
# ...
