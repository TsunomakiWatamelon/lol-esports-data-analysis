# %%
import bs4
import lxml
import pandas as pd
import urllib
import numpy
import retrieve

# %% [markdown]
# ### Obtenir les liens de tous les joueurs en LCK summer 2023

# %%
from bs4 import BeautifulSoup

# https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Summer%202022/

LCK_split_link_list =    [("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Summer%202023/", 2023, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Spring%202023/", 2023, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Summer%202022/", 2022, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Spring%202022/", 2022, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Summer%202021/", 2021, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Spring%202021/", 2021, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Summer%202020/", 2020, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCK%20Spring%202020/", 2020, "Spring")]

LPL_split_link_list =    [("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Summer%202023/", 2023, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Spring%202023/", 2023, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Summer%202022/", 2022, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Spring%202022/", 2022, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Summer%202021/", 2021, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Spring%202021/", 2021, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Summer%202020/", 2020, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LPL%20Spring%202020/", 2020, "Spring")]

LEC_split_link_list =    [("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Summer%202023/", 2023, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Spring%20Season%202023/", 2023, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Winter%202023/", 2023, "Winter"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Summer%202022/", 2022, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Spring%202022/", 2022, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Summer%202021/", 2021, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Spring%202021/", 2021, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Summer%202020/", 2020, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LEC%20Spring%202020/", 2020, "Spring")]

LCS_split_link_list =    [("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Summer%202023/", 2023, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Spring%202023/", 2023, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Summer%202022/", 2022, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Spring%202022/", 2022, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Summer%202021/", 2021, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Spring%202021/", 2021, "Spring"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Summer%202020/", 2020, "Summer"),
                          ("https://gol.gg/players/list/season-ALL/split-ALL/tournament-LCS%20Spring%202020/", 2020, "Spring")]





LCK_player_link_list = retrieve.getPlayerLinkList(LCK_split_link_list)
LPL_player_link_list = retrieve.getPlayerLinkList(LPL_split_link_list)
LEC_player_link_list = retrieve.getPlayerLinkList(LEC_split_link_list)
LCS_player_link_list = retrieve.getPlayerLinkList(LCS_split_link_list)

# %% [markdown]
# ### Obtenir les stats des joueurs

# %%
LCK_player_stats = retrieve.getPlayerStats(LCK_player_link_list)
LPL_player_stats = retrieve.getPlayerStats(LPL_player_link_list)
LEC_player_stats = retrieve.getPlayerStats(LEC_player_link_list)
LCS_player_stats = retrieve.getPlayerStats(LCS_player_link_list)
print(LCK_player_stats)
print(LPL_player_stats)
# Out:
#      Player  Year   Split    Record: Win Rate: KDA: CS per Minute:  \
# 0    Aiming  2023  Summer   34W - 6L       85%  9.1           10.5
# 1     Andil  2023  Summer   2W - 18L       10%  1.3            1.1
# 2       Bdd  2023  Summer   34W - 6L       85%  7.2            8.8
# 3     BeryL  2023  Summer  16W - 27L     37.2%  2.1            1.3
# 4     Bible  2023  Summer    8W - 5L     61.5%  2.8            1.1
# ..      ...   ...     ...        ...       ...  ...            ...
# 543   Viper  2020  Spring  16W - 29L     35.6%  3.9            9.9
# 544    Vsta  2020  Spring  13W - 22L     37.1%  3.4            8.3
# 545   Zenit  2020  Spring    1W - 4L       20%  1.6              8
# 546    bono  2020  Spring  24W - 17L     58.5%  4.1            5.2
# 547    kurO  2020  Spring  24W - 22L     52.2%  4.7            8.3
#
#     Gold Per Minute: Gold%: Kill Participation:
# 0                508    26%               75.2%
# 1                215  12.7%               64.9%
# ...

# %%
LCK_player_stats.to_csv("LCK_player_stats.csv", index=False)
LPL_player_stats.to_csv("LPL_player_stats.csv", index=False)
LEC_player_stats.to_csv("LEC_player_stats.csv", index=False)
LCS_player_stats.to_csv("LCS_player_stats.csv", index=False)

# %%
# LCK_player_stats = pd.read_csv("LCK_player_stats.csv")

# %% [markdown]
# ### Obtenir les liens de tous les equipes

# %%
from bs4 import BeautifulSoup

LCK_split_link_list = [("https://gol.gg/teams/list/season-S13/split-Summer/tournament-LCK%20Summer%202023/", 2023, "Summer"),
                       ("https://gol.gg/teams/list/season-S13/split-Spring/tournament-LCK%20Spring%202023/", 2023, "Spring"),
                       ("https://gol.gg/teams/list/season-S12/split-ALL/tournament-LCK%20Summer%202022/", 2022, "Summer"),
                       ("https://gol.gg/teams/list/season-S12/split-Spring/tournament-LCK%20Spring%202022/", 2022, "Spring"),
                       ("https://gol.gg/teams/list/season-S11/split-ALL/tournament-LCK%20Summer%202021/", 2021, "Summer"),
                       ("https://gol.gg/teams/list/season-S11/split-Spring/tournament-LCK%20Spring%202021/", 2021, "Spring"),
                       ("https://gol.gg/teams/list/season-S10/split-ALL/tournament-LCK%20Summer%202020/", 2020, "Summer"),
                       ("https://gol.gg/teams/list/season-S10/split-Spring/tournament-LCK%20Spring%202020/", 2020, "Spring")]

LPL_split_link_list =   [   ("https://gol.gg/teams/list/season-S13/split-Summer/tournament-LPL%20Summer%202023/", 2023, "Summer"),
                            ("https://gol.gg/teams/list/season-S13/split-Spring/tournament-LPL%20Spring%202023/", 2023, "Spring"),
                            ("https://gol.gg/teams/list/season-S12/split-ALL/tournament-LPL%20Summer%202022/", 2022, "Summer"),
                            ("https://gol.gg/teams/list/season-S12/split-Spring/tournament-LPL%20Spring%202022/", 2022, "Spring"),
                            ("https://gol.gg/teams/list/season-S11/split-ALL/tournament-LPL%20Summer%202021/", 2021, "Summer"),
                            ("https://gol.gg/teams/list/season-S11/split-Spring/tournament-LPL%20Spring%202021/", 2021, "Spring"),
                            ("https://gol.gg/teams/list/season-S10/split-ALL/tournament-LPL%20Summer%202020/", 2020, "Summer"),
                            ("https://gol.gg/teams/list/season-S10/split-Spring/tournament-LPL%20Spring%202020/", 2020, "Spring")]

LEC_split_link_list =   [   ("https://gol.gg/teams/list/season-ALL/split-ALL/tournament-LEC%20Summer%202023/", 2023, "Summer"),
                            ("https://gol.gg/teams/list/season-S13/split-Spring/tournament-LEC%20Spring%202023/", 2023, "Spring"),
                            ("https://gol.gg/teams/list/season-S12/split-ALL/tournament-LEC%20Summer%202022/", 2022, "Summer"),
                            ("https://gol.gg/teams/list/season-S12/split-Spring/tournament-LEC%20Spring%202022/", 2022, "Spring"),
                            ("https://gol.gg/teams/list/season-S11/split-ALL/tournament-LEC%20Summer%202021/", 2021, "Summer"),
                            ("https://gol.gg/teams/list/season-S11/split-Spring/tournament-LEC%20Spring%202021/", 2021, "Spring"),
                            ("https://gol.gg/teams/list/season-S10/split-ALL/tournament-LEC%20Summer%202020/", 2020, "Summer"),
                            ("https://gol.gg/teams/list/season-S10/split-Spring/tournament-LEC%20Spring%202020/", 2020, "Spring")]

LCS_split_link_list =   [   ("https://gol.gg/teams/list/season-S13/split-Summer/tournament-LCS%20Summer%202023/", 2023, "Summer"),
                            ("https://gol.gg/teams/list/season-S13/split-Spring/tournament-LCS%20Spring%202023/", 2023, "Spring"),
                            ("https://gol.gg/teams/list/season-S12/split-ALL/tournament-LCS%20Summer%202022/", 2022, "Summer"),
                            ("https://gol.gg/teams/list/season-S12/split-Spring/tournament-LCS%20Spring%202022/", 2022, "Spring"),
                            ("https://gol.gg/teams/list/season-S11/split-ALL/tournament-LCS%20Summer%202021/", 2021, "Summer"),
                            ("https://gol.gg/teams/list/season-S11/split-Spring/tournament-LCS%20Spring%202021/", 2021, "Spring"),
                            ("https://gol.gg/teams/list/season-S10/split-ALL/tournament-LCS%20Summer%202020/", 2020, "Summer"),
                            ("https://gol.gg/teams/list/season-S10/split-Spring/tournament-LCS%20Spring%202020/", 2020, "Spring")]


LCK_team_link_list = retrieve.getLCKTeamLinkList(LCK_split_link_list)
LPL_team_link_list = retrieve.getLPLTeamLinkList(LPL_split_link_list)
LEC_team_link_list = retrieve.getLECTeamLinkList(LEC_split_link_list)
LCS_team_link_list = retrieve.getLCSTeamLinkList(LCS_split_link_list)

# %% [markdown]
# ### Obtenir les roles des joueurs

# %%
LCK_player_role = retrieve.getPlayerRole(LCK_team_link_list)
LPL_player_role = retrieve.getPlayerRole(LPL_team_link_list)
LEC_player_role = retrieve.getPlayerRole(LEC_team_link_list)
LCS_player_role = retrieve.getPlayerRole(LCS_team_link_list)

# %%
print(LCK_player_role)
# Out:
#       Team  Year   Split     Role  Player
# 0    BRION  2023  Summer      TOP  Morgan
# 1    BRION  2023  Summer   JUNGLE    UmTi
# 2    BRION  2023  Summer      MID   Karis
# 3    BRION  2023  Summer      BOT    Hena
# 4    BRION  2023  Summer  SUPPORT  Effort
# ..     ...   ...     ...      ...     ...
# 634     T1  2020  Spring  SUPPORT  Effort
# 635     T1  2020  Spring      TOP   Roach
# 636     T1  2020  Spring   JUNGLE   Ellim
# 637     T1  2020  Spring      BOT  Effort
# 638     T1  2020  Spring  SUPPORT   Teddy
#
# [639 rows x 5 columns]

# %%
LCK_player_role.to_csv("LCK_player_role.csv", index=False)
LPL_player_role.to_csv("LPL_player_role.csv", index=False)
LEC_player_role.to_csv("LEC_player_role.csv", index=False)
LCS_player_role.to_csv("LCS_player_role.csv", index=False)

# %% [markdown]
# ### Stats finaux joueurs

# %%
LCK_players = pd.merge(LCK_player_role, LCK_player_stats, on=['Player', 'Year', 'Split'])
LPL_players = pd.merge(LPL_player_role, LPL_player_stats, on=['Player', 'Year', 'Split'])
LEC_players = pd.merge(LEC_player_role, LEC_player_stats, on=['Player', 'Year', 'Split'])
LCS_players = pd.merge(LCS_player_role, LCS_player_stats, on=['Player', 'Year', 'Split'])

# %%
print(LCK_players)
print(LPL_players)
# Out:
#       Team  Year   Split     Role  Player    Record: Win Rate: KDA:  \
# 0    BRION  2023  Summer      TOP  Morgan  15W - 30L     33.3%  2.1
# 1    BRION  2023  Summer   JUNGLE    UmTi  15W - 30L     33.3%  2.9
# 2    BRION  2023  Summer      MID   Karis  12W - 23L     34.3%  3.5
# 3    BRION  2023  Summer      BOT    Hena  15W - 30L     33.3%  3.3
# 4    BRION  2023  Summer  SUPPORT  Effort  15W - 30L     33.3%  2.6
# ..     ...   ...     ...      ...     ...        ...       ...  ...
# 634     T1  2020  Spring  SUPPORT  Effort  30W - 14L     68.2%  3.6
# 635     T1  2020  Spring      TOP   Roach    2W - 2L       50%  2.1
# 636     T1  2020  Spring   JUNGLE   Ellim    6W - 3L     66.7%  6.3
# 637     T1  2020  Spring      BOT  Effort  30W - 14L     68.2%  3.6
# 638     T1  2020  Spring  SUPPORT   Teddy  30W - 14L     68.2%  7.1
#
#     CS per Minute: Gold Per Minute: Gold%: Kill Participation:
# 0              8.9              390  22.3%                 52%
# ...

# %% [markdown]
# ### Obtenir stats equipes

# %%
LCK_team_stats  = retrieve.getTeamStats(LCK_split_link_list)
LPL_team_stats  = retrieve.getTeamStats(LPL_split_link_list)
LEC_team_stats  = retrieve.getTeamStats(LEC_split_link_list)
LCS_team_stats  = retrieve.getTeamStats(LCS_split_link_list)
# Out:
# [[2023, 'Summer', 'BRION', 'S13', 'KR', '45', '33.3%', '0.79', '1749', '-112', '32:17', '8.4', '10.7', '4.6', '6.9', '55.6', '46.7', '1.89', '41.9', '1.09', '54.4', '0.80', '0.0', '-277', '3.47', '0.60', '43.8', '34.5', '1848', '3.5', '1.47', '1.87'], [2023, 'Summer', 'Dplus KIA', 'S13', 'KR', '40', '60.0%', '1.23', '1859', '78', '31:38', '13.1', '10.7', '6.5', '5.1', '47.5', '45.0', '2.65', '58.6', '0.98', '48.8', '1.18', '0.1', '638', '4.83', '0.88', '61.6', '33.8', '2308', '3.6', '1.46', '1.65'], [2023, 'Summer', 'DRX', 'S13', 'KR', '43', '37.2%', '0.72', '1733', '-159', '30:40', '9.7', '13.4', '4.6', '6.8', '39.5', '37.2', '1.77', '39.3', '1.00', '50.0', '0.72', '0.0', '-1036', '4.26', '0.63', '38.2', '32.6', '1964', '3.4', '1.42', '1.72'], [2023, 'Summer', 'Gen.G eSports', 'S13', 'KR', '39', '82.1%', '1.77', '1969', '275', '29:57', '14.4', '8.2', '8.0', '3.6', '71.8', '76.9', '2.74', '64.6', '0.90', '44.9', '1.05', '0.3', '1232', '5.51', '0.92', '73.4', '35.7', '2269', '3.3', '1
# ...

# %%
print(LCK_team_stats)
# Out:
#     Year   Split                 Name Season Region Games Win rate   K:D  \
# 0   2023  Summer                BRION    S13     KR    45    33.3%  0.79
# 1   2023  Summer            Dplus KIA    S13     KR    40    60.0%  1.23
# 2   2023  Summer                  DRX    S13     KR    43    37.2%  0.72
# 3   2023  Summer        Gen.G eSports    S13     KR    39    82.1%  1.77
# 4   2023  Summer  Hanwha Life eSports    S13     KR    41    65.9%  1.27
# ..   ...     ...                  ...    ...    ...   ...      ...   ...
# 75  2020  Spring  Hanwha Life eSports    S10     KR    45    37.8%  0.72
# 76  2020  Spring           KT Rolster    S10     KR    46    52.2%  1.05
# 77  2020  Spring       Sandbox Gaming    S10     KR    44    36.4%  0.84
# 78  2020  Spring    SeolHaeOne Prince    S10     KR    43    39.5%  0.75
# 79  2020  Spring                   T1    S10     KR    44    68.2%  1.50
#
#      GPM   GDM  ... TD@15  GD@15   PPG NASHPG NASH%   CSM   DPM  WPM  VWPM  \
# ...

# %%
LCK_team_stats.to_csv("LCK_team_stats.csv", index=False)
LPL_team_stats.to_csv("LPL_team_stats.csv", index=False)
LEC_team_stats.to_csv("LEC_team_stats.csv", index=False)
LCS_team_stats.to_csv("LCS_team_stats.csv", index=False)
